# %%
import sys

import numpy as np

sys.path.append('/Users/markbills/Library/CloudStorage/OneDrive-Transformativ,LLC/Clients/Ovation Holdings/src')

# Azure Data Lake libraries
import azure_data_lake_interface as adl

# Data analysis libraries
import pandas as pd

# Helper function libraries
import helper_functions as hf

# %%
# attach to the data lake
config = hf.load_config("config/datalake_config.json", flush_cache=True)
service_client = adl.get_azure_service_client(config["blob_url"])
file_system_client = adl.get_azure_file_system_client(service_client, "consolidated")

# %%
# get data
transactions, line_items = adl.get_transactions_and_line_items(file_system_client, "CustInvc", data_state="enhanced")
save_line_items = line_items.copy()

# %%
high_prices = line_items[~line_items.highest_recent_price.isna()].copy()
high_prices["difference"] = high_prices.quote_po_rate - high_prices.highest_recent_price
high_prices["pct_diff"] = round(high_prices.difference/high_prices.quote_po_rate * 100, 2)

# %%
quote_matches = high_prices[abs(high_prices.difference) < 1]
quote_higher = high_prices[high_prices.difference >= 1]
quote_lower = high_prices[high_prices.difference <= -1]

# %%
print(f"quote matches: {(quote_matches.shape[0]/high_prices.shape[0])*100:.2f}%")
print(f"quote below: {(quote_lower.shape[0]/high_prices.shape[0])*100:.2f}%")
print(f"quote above: {(quote_higher.shape[0]/high_prices.shape[0])*100:.2f}%")
# Out:
# quote matches: 58.29%
# quote below: 35.65%
# quote above: 6.07%

# %%
quote_lower[['difference', 'pct_diff']].describe()
# Out:
# /Users/markbills/Library/CloudStorage/OneDrive-Transformativ,LLC/Clients/Ovation Holdings/Phase 2/Operational Visibility Workstream/MarginAnalysis/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           difference  pct_diff
# count   87071.000000  87071.00
# mean     -397.050655      -inf
# std      3738.450575       NaN
# min   -347628.740000      -inf
# 25%      -139.950000    -65.63
# 50%       -34.670000    -25.67
# 75%        -7.160000     -8.17
# max        -1.000000     -0.00

# %% [markdown]
# ### Sales by Commission Type, Jan-2023 to Apr-2025

# %%
line_items['Month'] = line_items.created_date.dt.strftime('%Y-%m')

# Group by Month and commission_or_mfr_direct to get total sales
sales_by_month = line_items.groupby(['Month', 'commission_or_mfr_direct'])['total_amount'].sum().reset_index()

# Pivot the data to show commission vs non-commission sales side by side
sales_pivot = sales_by_month.pivot(index='Month',
                                   columns='commission_or_mfr_direct',
                                   values='total_amount')
sales_pivot.fillna(0, inplace=True)

# Rename columns for clarity
sales_pivot.columns = ['Non-Commission Sales', 'Commission Sales']

# Add total sales column
sales_pivot['Total Sales'] = sales_pivot.sum(axis=1)

print("Monthly Sales by Commission Type:")
print(sales_pivot.to_string(float_format=lambda x: f'${x:,.2f}'))
# Out:
# Monthly Sales by Commission Type:
#          Non-Commission Sales  Commission Sales    Total Sales
# Month
# 2022-01         $6,135,490.58             $0.00  $6,135,490.58
# 2022-02         $6,690,763.83             $0.00  $6,690,763.83
# 2022-03         $9,466,324.30             $0.00  $9,466,324.30
# 2022-04         $9,827,403.56             $0.00  $9,827,403.56
# 2022-05         $9,799,709.55             $0.00  $9,799,709.55
# 2022-06        $13,786,530.83           $564.42 $13,787,095.25
# 2022-07        $12,170,738.34             $0.00 $12,170,738.34
# 2022-08        $14,751,701.22         $3,526.50 $14,755,227.72
# 2022-09        $13,599,400.24         $5,928.69 $13,605,328.93
# 2022-10        $19,878,089.09        $35,091.10 $19,913,180.19
# 2022-11        $14,384,654.66       $126,461.20 $14,511,115.86
# 2022-12        $12,313,286.82        $42,081.05 $12,355,367.87
# 2023-01        $12,110,953.00         $6,807.42 $12,117,760.42
# 2023-02        $12,570,132.19        $13,056.00 $12,583,188.19
# 2023-03        $17,184,503.66        $13,003.76 $17,197,507.42
# 2023-04        $15,070,125.87        $31,682.30 $15,101,808.17
# 2023-05        $18,940,421.39        $60,740.50 $19,001,161.89
# 2023-06        $18,002,801.99        $27,448.01 $18,030,250.00
# 2023-07        $15,866,272.71        $28,801.50 $15,895,074.21
# 2023-08        $20,178,088.32         $6,554.00 $20,184,642.32
# 2023-09        $17,134,835.88     $1,531,828.85 $18,666,664.73
# 2023-10        $18,536,405.58     $1,820,802.17 $20,357,207.75
# 2023-11        $15,347,262.41     $1,672,397.34 $17,019,659.75
# 2023-12        $14,544,489.07     $1,343,238.91 $15,887,727.98
# 2024-01        $14,361,706.29     $1,456,519.25 $15,818,225.54
# 2024-02        $18,694,948.10     $1,759,452.28 $20,454,400.38
# 2024-03        $16,978,099.47     $1,820,266.67 $18,798,366.14
# 2024-04        $19,881,960.59     $1,669,577.37 $21,551,537.96
# 2024-05        $21,128,987.70     $1,682,999.83 $22,811,987.53
# 2024-06        $19,814,648.77     $1,672,781.00 $21,487,429.77
# 2024-07        $16,936,391.60     $1,566,754.23 $18,503,145.83
# 2024-08        $20,696,943.37     $1,774,418.91 $22,471,362.28
# 2024-09        $22,744,100.90     $1,593,532.50 $24,337,633.40
# 2024-10        $21,966,738.93     $1,715,702.36 $23,682,441.29
# 2024-11        $19,051,291.79     $1,524,729.26 $20,576,021.05
# 2024-12        $18,007,996.91     $1,634,590.38 $19,642,587.29
# 2025-01        $17,819,414.46     $1,439,795.93 $19,259,210.39
# 2025-02        $17,539,099.54     $1,668,448.32 $19,207,547.86
# 2025-03        $19,699,466.10     $1,907,584.76 $21,607,050.86
# 2025-04        $11,158,631.00     $1,387,182.85 $12,545,813.85

# %%
print(f"${sales_pivot['Non-Commission Sales'].sum():,.2f}",
      f"${sales_pivot['Commission Sales'].sum():,.2f}",
      f"${sales_pivot['Total Sales'].sum():,.2f}")
# Out:
# $634,770,810.60 $33,044,349.62 $667,815,160.22

# %% [markdown]
# ### Item Type Distribution for Non-Commission Line Items

# %%
comm_lines = line_items.query('commission_or_mfr_direct == True')
comm_lines.item_type.value_counts()
# Out:
# item_type
# Inventory Item                7472
# Non-inventory Item            1918
# Service                         32
# Assembly/Bill of Materials       3
# Name: count, dtype: int64

# %%
comm_lines.query('item_type == "Inventory Item"')
# Out:
#           amount assembly_component cost_estimate_type         created_from  \
# 49819    3526.50                  F             CUSTOM  Sales Order #305726
# 52731    1424.12                  F             CUSTOM  Sales Order #302486
# 52732    1145.29                  F             CUSTOM  Sales Order #302486
# 52733    2881.28                  F             CUSTOM  Sales Order #302486
# 52734     478.00                  F         PURCHPRICE  Sales Order #302486
# ...          ...                ...                ...                  ...
# 393356   3670.00                  F     PURCHORDERRATE  Sales Order #437372
# 393370  11420.00                  F     PURCHORDERRATE  Sales Order #435887
# 393391   2133.05                  F     PURCHORDERRATE  Sales Order #423255
# 393433   4800.00                  F     PURCHORDERRATE  Sales Order #437127
# 393442   6516.00                  F     PURCHORDERRATE  Sales Order #437252
#
#         custcol_ava_taxamount  custcol_sa_quote_po_rate custom_manufacturer  \
# 49819                    0.00                       0.0                 CDC
# 52731                    0.00                       0.0          McCrometer
# 52732                    0.00                       0.0          McCrometer
# 52733                    0.00                       0.0            Yokogawa
# 52734                    0.00                       0.0            Yokogawa
# ...                       ...                       ...                 ...
# 393356                   0.00                       0.0                 MSA
# 393370                   0.00                       0.0                 MSA
# 393391                   0.00                       0.0            Yokogawa
# 393433                   0.00                       0.0            Yokogawa
# 393442                 407.25                       0.0            Yokogawa
#
#        customer_id                                        description  \
# 49819          689                                         SANITRX 2"
# 52731       290878  MCCROMETER 3" WAFER V-CONE DP FLOWMETER.\r\nP/...
# 52732       290878  MCCROMETER 2" WAFER V-CONE DP FLOWMETER   \r\n...
# 52733       290878  YOKOGAWA EJA110E DP TRANS - REMOTE MOUNT  * HI...
# 52734       290878  C13ST-3TSA0-S4-NNNNN-NNNN\r\n\r\nYokogawa 3-Va...
# ...            ...                                                ...
# 393356      156220  A-X5000-0-F-0-1-0-16-00-0\r\n\r\nA-X5000: MSA ...
# 393370      412873  A-CG5000-0-4-1-0\r\nMSA CHILLGARD 5000\r\n4 CH...
# 393391       15882  FX1002-7-2-L/C7/M1/P1/USB1/S1\r\n \r\nFX1002: ...
# 393433       32942  UT35A-L00-11-00\r\nUT35A: Yokogawa Digital Ind...
# 393442      407869  EJA530E: Yokogawa Gauge Pressure Transmitter, ...
#
#                                         display_name  ...  level_3_category  \
# 49819                        Gas/Liquid Rupture Disc  ...     Not Specified
# 52731                                           null  ...     Not Specified
# 52732                                           null  ...     Not Specified
# 52733                                           null  ...     Not Specified
# 52734      Yokogawa 3-Valve Manifold (Stocked Model)  ...          Manifold
# ...                                              ...  ...               ...
# 393356                MSA X5000 Gas Monitor - Oxygen  ...         Fixed Gas
# 393370             Deplete inventory, Do not reorder  ...       Controllers
# 393391                   Yokogawa Paperless Recorder  ...     Data Recorder
# 393433  Yokogawa Digital Indicating Limit Controller  ...     Not Specified
# 393442                                          null  ...         Gauge/Abs
#
#         level_4_category  level_5_category  level_6_category        vsi_mfr  \
# 49819      Not Specified     Not Specified     Not Specified  Not Specified
# 52731      Not Specified     Not Specified     Not Specified  Not Specified
# 52732      Not Specified     Not Specified     Not Specified  Not Specified
# 52733      Not Specified     Not Specified     Not Specified  Not Specified
# 52734      Not Specified               New           3 valve  Not Specified
# ...                  ...               ...               ...            ...
# 393356             X5000               New     Not Specified  Not Specified
# 393370        Chillagard               New     Not Specified  Not Specified
# 393391                FX               New     Not Specified  Not Specified
# 393433     Not Specified     Not Specified     Not Specified  Not Specified
# 393442            EJA310               New                 B  Not Specified
#
#         vsi_item_category total_cost gross_profit  gross_profit_percent  \
# 49819       Not Specified    2548.80       977.70              0.277244
# 52731       Not Specified    1210.50       213.62              0.150001
# 52732       Not Specified     973.50       171.79              0.149997
# 52733       Not Specified    2701.20       180.08              0.062500
# 52734       Not Specified     358.50       119.50              0.250000
# ...                   ...        ...          ...                   ...
# 393356      Not Specified    3670.00         0.00              0.000000
# 393370      Not Specified   11420.00         0.00              0.000000
# 393391      Not Specified    2133.05         0.00              0.000000
# 393433      Not Specified    4800.00         0.00              0.000000
# 393442      Not Specified    6516.00         0.00              0.000000
#
#           Month
# 49819   2022-08
# 52731   2022-09
# 52732   2022-09
# 52733   2022-09
# 52734   2022-09
# ...         ...
# 393356  2025-04
# 393370  2025-04
# 393391  2025-04
# 393433  2025-04
# 393442  2025-04
#
# [7472 rows x 52 columns]
